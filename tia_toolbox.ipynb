# %%
"""Import modules required to run the Jupyter notebook."""

# Clear logger to use tiatoolbox.logger
import logging

if logging.getLogger().hasHandlers():
    logging.getLogger().handlers.clear()


import shutil
import warnings
from pathlib import Path

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import requests

from tiatoolbox import logger
from tiatoolbox.models.engine.patch_predictor import PatchPredictor
from tiatoolbox.utils.misc import imwrite
from tiatoolbox.utils.visualization import (
    overlay_prediction_mask,
    overlay_probability_map,
)
from tiatoolbox.wsicore.wsireader import WSIReader

mpl.rcParams["figure.dpi"] = 140  # for high resolution figure in notebook
mpl.rcParams["figure.facecolor"] = "white"  # To make sure text is visible in dark mode

# %%
wsi_file_name = Path("C:/Users/thiba/Documents/INSA_2024-2025/Semestre1/projet_5BIM/donnée/transfer_8262829_files_4fcee2db/Slides_cases_BAP1_test/03000195-00072192-1_1_1_HES.svs")

# %%
wsi_file_list = [
    wsi_file_name,
]  # the list of WSIs to process- in this example we just use a single WSI.

# %% [markdown]
# Number of workers of the machine

# %%
import multiprocessing
print(multiprocessing.cpu_count())
# Out:
# 12

# %%
tumour_predictor = PatchPredictor(
    pretrained_model="resnet18-idars-tumour",
    batch_size=64,
    num_loader_workers=12,
)

# %%
#%pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
import numpy
import torch
print(torch.cuda.is_available())
# Out:
# False

# %%
tumour_output = tumour_predictor.predict(
    imgs=wsi_file_list,
    mode="wsi",
    return_probabilities=True,
    on_gpu=False,
)
# Out:
# Read: Scale > 1.This means that the desired resolution is higher than the WSI baseline (maximum encoded resolution). Interpolation of read regions may occur.
# Read: Scale > 1.This means that the desired resolution is higher than the WSI baseline (maximum encoded resolution). Interpolation of read regions may occur.
#   0%|                                                    | 0/23 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 tumour_output = tumour_predictor.predict(
#       2     imgs=wsi_file_list,
#       3     mode="wsi",
#       4     return_probabilities=True,
#       5     on_gpu=False,
#       6 )
#
# ...
